# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import re
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.pipeline import Pipeline
from scipy import sparse
from sklearn.svm import LinearSVC
import json
from sklearn.model_selection import train_test_split
import copy

# %%
with open('dictionaries/train.json', encoding="UTF-8") as f:
    raw_train = json.load(f)

# %%
len(raw_train)
# Out:
# 8263

# %%
ru_token(raw_train[0]["text"])
# Out:
# ['Досудебное',
#  'расследование',
#  'по',
#  'факту',
#  'покупки',
#  'ЕНПФ',
#  'пакета',
#  'облигаций',
#  'ТОО',
#  'Бузгул',
#  'Аурум',
#  'было',
#  'начато',
#  'по',
#  'инициативе',
#  'Национального',
#  'банка',
#  'РК',
#  'сообщил',
#  'директор',
#  'департамента',
#  'защиты',
#  'прав',
#  'потребителей',
#  'и',
#  'финансовых',
#  'услуг',
#  'Нацбанка',
#  'Казахстана',
#  'Александр',
#  'Терентьев',
#  'Основанием',
#  'для',
#  'досудебного',
#  'расследования',
#  'стало',
#  'обращение',
#  'Национального',
#  'банка',
#  'письмо',
#  'от',
#  'ноября',
#  'года',
#  'Было',
#  'обращение',
#  'Национального',
#  'банка',
#  'в',
#  'правоохранительные',
#  'органы',
#  'Нам',
#  'эта',
#  'сделка',
#  'показалась',
#  'сомнительной',
#  'недостаточно',
#  'корректной',
#  'поэтому',
#  'Нацбанк',
#  'ноября',
#  'года',
#  'обратился',
#  'в',
#  'правоохранительные',
#  'органы',
#  'Это',
#  'то',
#  'что',
#  'я',
#  'могу',
#  'озвучить',
#  'на',
#  'сегодня',
#  'Идёт',
#  'следствие',
#  'проводится',
#  'проверка',
#  'сказал',
#  'Терентьев',
#  'декабря',
#  'в',
#  'Нацбанке',
#  'заявили',
#  'что',
#  'не',
#  'знают',
#  'что',
#  'стало',
#  'основанием',
#  'для',
#  'проверки',
#  'ЕНПФ',
#  'декабря',
#  'факт',
#  'проведения',
#  'проверки',
#  'в',
#  'АО',
#  'Единый',
#  'накопительный',
#  'пенсионный',
#  'фонд',
#  'подтвердился',
#  'Национального',
#  'банка',
#  'сообщила',
#  'что',
#  'проверку',
#  'проводят',
#  'по',
#  'операциям',
#  'совершённым',
#  'АО',
#  'ЕНПФ',
#  'в',
#  'отношении',
#  'инвестирования',
#  'собственных',
#  'активов',
#  'Также',
#  'в',
#  'финрегуляторе',
#  'сообщали',
#  'что',
#  'по',
#  'сделке',
#  'ЕНПФ',
#  'на',
#  'сумму',
#  'в',
#  'пять',
#  'млрд',
#  'заведено',
#  'уголовное',
#  'дело',
#  'В',
#  'Нацбанке',
#  'заверяют',
#  'что',
#  'всё',
#  'происходящее',
#  'не',
#  'затрагивает',
#  'пенсионных',
#  'накоплений',
#  'казахстанцев',
#  'Если',
#  'вы',
#  'нашли',
#  'ошибку',
#  'в',
#  'тексте',
#  'выделите',
#  'ее',
#  'мышью',
#  'и',
#  'нажмите']

# %%
def ru_token(string):
    """russian tokenize based on nltk.word_tokenize. only russian letter remaind."""
    return [i for i in word_tokenize(string) if re.match(r'[\u0400-\u04ffа́]+$', i)]

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 3), tokenizer=ru_token, stop_words=stopwords.words('russian'),
                        min_df=3,
                        use_idf=1, smooth_idf=1, sublinear_tf=1)

# %%
tfidf.fit([i['text'] for i in raw_train])
# Out:
# f:\programming\python\economanalyzer\venv\lib\site-packages\sklearn\feature_extraction\text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# TfidfVectorizer(min_df=3, ngram_range=(1, 3), smooth_idf=1,
#                 stop_words=['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с',
#                             'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его',
#                             'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы',
#                             'по', 'только', 'ее', 'мне', ...],
#                 sublinear_tf=1,
#                 tokenizer=<function ru_token at 0x0000018707181A68>, use_idf=1)

# %%
class NBFeaturer(BaseEstimator, ClassifierMixin):
    """from https://www.kaggle.com/sermakarevich"""
    def __init__(self, alpha):
        self.alpha = alpha

    def preprocess_x(self, x, r):
        return x.multiply(r)

    def transform(self, x):
        x_nb = self.preprocess_x(x, self._r)
        return x_nb

    def fit(self, x, y):
        self._r = sparse.csr_matrix(np.log(self.pr(x, 1, y) / self.pr(x, 0, y)))
        return self

    def pr(self, x, y_i, y):
        p = x[y == y_i].sum(0)
        return (p + self.alpha) / ((y == y_i).sum() + self.alpha)

# %%
nbf = NBFeaturer(alpha=10)
model = LinearSVC(C=4, max_iter=30) # One-vs.-rest balanced category with 1:1:1

p = pipeline = Pipeline([
    ('nbf', nbf),
    ('lr', model)
])

# %%
train, val = train_test_split(raw_train, test_size=0.2, random_state=2018)

# %%
train_x = tfidf.transform([i['text'] for i in train])
lab = LabelEncoder()
lab.fit([i['sentiment'] for i in raw_train])
train_y = []
for i in range(3):
    train_y.append((lab.transform([d['sentiment'] for d in train]) == i).astype(int))
val_x = tfidf.transform([d['text'] for d in val])
val_y = lab.transform([d['sentiment'] for d in val])

# %%
a = lab.fit_transform([i['sentiment'] for i in raw_train])
w = [(len(a) - np.sum(a == i))/(2 * np.sum(a == i)) for i in range(max(a)+1)]

# %%
pred = []
test_pred = []
for i in range(3):
    p.get_params()['lr'].class_weight = {0: 1, 1:w[i] }
    p.fit(train_x, train_y[i])
    pred.append(p.decision_function(val_x))
# Out:
# f:\programming\python\economanalyzer\venv\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
accuracy_score(val_y, np.argmax(np.array(pred), axis=0))
# Out:
# 0.6860254083484574

# %%
df = pd.read_csv("input2.csv", error_bad_lines=False, names=["link", "text", "date"])

# %%
df[["text", "result"]].head(50)
# Out:
#                                                                           text  \
# 0       В МЭР рассказали о проблемах в реализации совместных проектов с Кубой
# 1                                В Москве отметили снижение числа безработных
# 2     Дерипаска дважды за день раскритиковал политику ЦБ в отношении аграриев
# 3                              Цены на сахар и масло ограничат до конца марта
# 4      Структура банка "Россия" купила винодельческое предприятие "Массандра"
# 5                                   Медведев оценил закон об удаленной работе
# 6                    Глава МЭР рассказал о мерах стабилизации цен на продукты
# 7     Мишустин оценил идею ввести планку колебаний цен на социальные продукты
# 8                   Россия вводит новые экспортные пошлины на зерно и пшеницу
# 9                Куда двинется рубль? Прогноз главного экономиста Альфа-банка
# 10          Московские власти не планируют сокращать инвестиционные программы
# 11                     Официальный курс евро на вторник снизился на 19 копеек
# 12      Мишустин призвал оставить производство продуктов выгодным для бизнеса
# 13             Мишустин продлил программы поддержки аэропортов и авиакомпаний
# 14    Минсельхоз назвал условие отмены пошлины на импорт тростникового сахара
# 15             Песков описал рабочий стиль Путина при решении важных вопросов
# 16    Песков заявил, что ситуация с ценами на бензин не вызывает беспокойства
# 17                            В Кремле прокомментировали рост цен на продукты
# 18       На совещании у Путина не затрагивался вопрос о кредитах для аграриев
# 19    Песков призвал дождаться инструментов правительства для регулировки цен
# 20                                Россия введет экспортную пошлину на пшеницу
# 21      Производители сахара, хлеба и переработчики муки получат господдержку
# 22                                       Россия введет квоту на экспорт зерна
# 23   Эксперт не согласился с тем, как Дерипаска объяснил рост цен на продукты
# 24                             Акции Сбербанка обновили исторический максимум
# 25                ВТБ снизил ставки по кредитам для малого и среднего бизнеса
# 26                    Московские власти оценили влияние пандемии на экономику
# 27  В России утвердили правила выдачи субсидий на разработку вакцины от COVID
# 28                  В Калининградской области выдали первый займ самозанятому
# 29             "Коммунисты России" предложили национализировать торговые сети
# 30               Россия продлила продовольственное эмбарго до конца 2021 года
# 31                                    Дерипаска объяснил рост цен на продукты
# 32  Акции украинской компании Fishing Company по суду отошли госкорпорации РФ
# 33      Эксперт оценил меры по фиксированию цен на сахар и подсолнечное масло
# 34           Индекс Мосбиржи впервые в истории преодолел отметку 3300 пунктов
# 35                  СМИ сообщили о планируемой заморозке цен на масло и сахар
# 36           В ожидании сырьевого года: в Saxo Bank предрекли падение доллара
# 37  В Югре заявили о готовности к строительству завода Tenaris и "Северстали"
# 38         Суд на БВО арестовал акции Fishing Company по делу Проминвестбанка
# 39                      Банкир спрогнозировал ослабление доллара до 65 рублей
# 40  СМИ: цены на сахар и подсолнечное масло могут зафиксировать на три месяца
# 41        Финансист дал совет, с какой суммой лучше не спешить на рынок акций
# 42           Минсельхоз: бизнес готов реагировать на предложения снизить цены
# 43      "Это не шуточки". Путин раскритиковал министров из-за цен на продукты
# 44      Путин потребовал не рассказывать ему "сказки" о ситуации с ростом цен
# 45       Путин раскритиковал правительство из-за пошлин на подсолнечное масло
# 46                             Путин назвал рост цен на макароны недопустимым
# 47              Путин потребовал за неделю решить вопрос с ценами на продукты
# 48           Путин поручил правительству решить вопрос с ростом цен за неделю
# 49       Ретейлеры пообещали обеспечить россиян продуктами по доступным ценам
#
#       result
# 0   0.251165
# 1  -0.728133
# 2  -0.949828
# 3  -0.816628
# 4  -0.871995
# 5  -0.296046
# 6  -0.697207
# 7  -0.558596
# 8  -0.420460
# 9  -0.785921
# 10 -0.567087
# 11 -0.694490
# 12 -0.514946
# 13 -0.673023
# 14 -0.477791
# 15 -0.801245
# 16 -0.825036
# 17 -0.747505
# 18 -0.834027
# 19 -0.784568
# 20 -0.622284
# 21 -0.626250
# 22 -0.335809
# 23 -0.692064
# 24 -0.337253
# 25 -0.227865
# 26 -0.573801
# 27 -0.743568
# 28 -0.651266
# 29 -0.685151
# 30 -0.568816
# 31 -0.667996
# 32 -0.551049
# 33 -0.623366
# 34 -0.240269
# 35 -0.805965
# 36 -0.755976
# 37 -0.563377
# 38 -0.633716
# 39 -0.843347
# 40 -0.832050
# 41 -0.600685
# 42 -0.662891
# 43 -0.679265
# 44 -0.719318
# 45 -0.867370
# 46 -0.748304
# 47 -0.761188
# 48 -0.813408
# 49 -0.832845

# %%
pd.set_option("display.max_colwidth", 160)

# %%
testdata = tfidf.transform(df["text"])

# %%
result2 = p.decision_function(testdata)

# %%
df["result"] = result2

# %%
tfidf.fit(df["text"])
# Out:
# f:\programming\python\economanalyzer\venv\lib\site-packages\sklearn\feature_extraction\text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# TfidfVectorizer(min_df=3, ngram_range=(1, 3), smooth_idf=1,
#                 stop_words=['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с',
#                             'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его',
#                             'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы',
#                             'по', 'только', 'ее', 'мне', ...],
#                 sublinear_tf=1,
#                 tokenizer=<function ru_token at 0x0000018707181A68>, use_idf=1)
