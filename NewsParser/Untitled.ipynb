# %%
from tqdm import tqdm
import csv
import os
import pandas as pd

df = pd.read_csv('ria_tags2.csv', names=['date', 'text', 'link', 'tags'])

# %%
df.head(50)
# Out:
#                                                                                                                                                                date  \
# 14-12-2020  В МЭР рассказали о проблемах в реализации совм...  https://ria.ru/20201214/kuba-1589117765.html                                                  Россия
#             В Москве отметили снижение числа безработных       https://ria.ru/20201214/bezrabotnye-1589114731...                                             Москва
#             Дерипаска дважды за день раскритиковал политик...  https://ria.ru/20201214/deripaska-1589112849.html                                   Дмитрий Медведев
#             Цены на сахар и масло ограничат до конца марта     https://ria.ru/20201214/produkty-1589111865.html                                   Максим Решетников
#             Структура банка "Россия" купила винодельческое...  https://ria.ru/20201214/massandra-1589111431.html                                             Россия
# ...
